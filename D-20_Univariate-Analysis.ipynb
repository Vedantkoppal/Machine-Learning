# %% [markdown]
# # Analysing individual Cols independently

# %% [markdown]
# ## Types of Data
# <br>
# <h3>1. Numerical</h3>
# <h3>2. Categorical</h3>

# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('Datasets/titanic.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass  \
# 0           0            1         0       3
# 1           1            2         1       1
# 2           2            3         1       3
# 3           3            4         1       1
# 4           4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %% [markdown]
# <h1>1. Categorical Data</h1>
# <h2>a. CountPlot</h2>

# %%
# Survived
# sns.countplot(df['Survived'])
df['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
# Pclass
print(df['Pclass'].value_counts())
df['Pclass'].value_counts().plot(kind='bar')
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64
# <Axes: >

# %%
df1=df.groupby('Pclass')['Fare'].mean()
print(df['Fare'].mean())
# Out:
# 32.204207968574636

# %%
df1=df['Pclass']==1

# %%
df1
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888    False
# 889     True
# 890    False
# Name: Pclass, Length: 891, dtype: bool

# %%
# Embarked
df['Embarked'].value_counts().plot(kind='bar')
df['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %% [markdown]
# <h3>b. Piechart</h3>

# %%
df['Sex'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='Sex'>

# %% [markdown]
# <h1>2. Numerical Data</h1>
# <h3>a. Histogram</h3>

# %%
import matplotlib.pyplot as plt

# %%
# Age
plt.hist(df['Age'],bins=10)
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# <h3>b. Distplot</h3>

# %% [markdown]
# ## Probability Distribution Function
# ## Gives probability of x-axis values by a curve

# %%
ax=sns.displot(df['Age'],bins=10,kde=True)

# %% [markdown]
# ## c. BoxPlot
# ### min=Q1-1.5*IQR
# ### max=Q3+1.5*IQR

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.boxplot(df['Fare'])
# Out:
# <Axes: ylabel='Fare'>

# %% [markdown]
# ## Generel purpose

# %%
print(df['Fare'].min())
print(df['Fare'].max())
print(df['Fare'].std())
print(df['Fare'].skew()) # If skew==0 the data is perfectly balanced!(Normal Distribution)
# Out:
# 0.0
# 512.3292
# 49.6934285971809
# 4.787316519674893
